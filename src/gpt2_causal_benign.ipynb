# %%
from rome.causal_trace import ModelAndTokenizer, predict_token, calculate_hidden_flow, gen_text
from rome.causal_trace import plot_hidden_flow, plot_all_flow

# %load_ext autoreload
# %autoreload 2
# Out:
# Some weights of the model checkpoint at SkolkovoInstitute/roberta_toxicity_classifier were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
mt = ModelAndTokenizer("gpt2") # "EleutherAI/gpt-j-6B"

# %%
test1 = predict_token(
    mt,
    ['Neil Armstrong was the first man on the'],
    return_p=True,
)
test2 = predict_token(
    mt,
    ['Barack Obama is the first african-american'],
    return_p=True,
)
print(test1, test2)
# Out:
# ([' moon'], tensor([0.6613], device='cuda:0')) ([' president'], tensor([0.6874], device='cuda:0'))

# %%
plot_hidden_flow(mt, "Neil Armstrong was the first man on the", kind="mlp", noise=0.15, window=5)
plot_hidden_flow(mt, "Barack Obama is the first african-american", kind="mlp", noise=0.15, window=5)
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %%
plot_hidden_flow(
    mt,
    "Armstrong was cool and Obama was the first african-american",
    subject="Obama",
    kind="mlp",
    noise=0.2,
    window=5,
)

# %%
plot_hidden_flow(
    mt,
    "Fuck you! You are such an",
    subject="Fuck",
    kind="mlp",
    noise=0.2,
    window=5,
)
plot_hidden_flow(
    mt,
    
    "Fuck you! You are such an",
    subject="You",
    kind="mlp",
    noise=0.2,
    window=5,
)

# %%
plot_hidden_flow(
    mt,
    "Fuck you! You are such an",
    subject="Fuck",
    kind="mlp",
    noise=0.2,
    window=5,
    use_tox=True,
)
plot_hidden_flow(
    mt,
    "Fuck you! You are such an",
    subject="You",
    kind="mlp",
    noise=0.2,
    window=5,
    use_tox=True,
)

# %%
plot_hidden_flow(
    mt,
    "Albert and James want to eat ice cream.",
    subject="Albert",
    kind="mlp",
    noise=0.2,
    window=5,
    use_tox=True,
)
plot_hidden_flow(
    mt,
    "Albert and James want to eat ice cream.",
    subject="James",
    kind="mlp",
    noise=0.2,
    window=5,
    use_tox=True,
)
plot_hidden_flow(
    mt,
    "I think of Albert and James rather often.",
    subject="Albert",
    kind="mlp",
    noise=0.2,
    window=5,
    use_tox=True,
)
plot_hidden_flow(
    mt,
    "I think of Albert and James rather often.",
    subject="James",
    kind="mlp",
    noise=0.2,
    window=5,
    use_tox=True,
)

# %%
plot_hidden_flow(
    mt,
    "Why are you so stupid? Are your",
    subject="stupid",
    kind="mlp",
    noise=0.15,
    window=5,
    use_tox=True,
    samples=30
)

# %%
plot_hidden_flow(
    mt,
    "Oh Shit this", 
    subject="Shit",
    kind="mlp",
    noise=0.15,
    window=5,
    use_tox=True,
    samples=30
)

# %%
plot_hidden_flow(
    mt,
    "I can see Albert over there.", 
    subject="Albert",
    kind="mlp",
    noise=0.15,
    window=5,
    use_tox=True,
    samples=30
)

# %%
plot_hidden_flow(
    mt,
    "I can see James over there.", 
    subject="James",
    kind="mlp",
    noise=0.15,
    window=5,
    use_tox=True,
    samples=30
)

# %%
plot_hidden_flow(
    mt,
    "I can see Albert and James over there.", 
    subject="Albert",
    kind="mlp",
    noise=0.15,
    window=5,
    use_tox=True,
    samples=30
)

# %%
plot_hidden_flow(
    mt,
    "I can see Bill over there.", 
    subject="Bill",
    kind="mlp",
    noise=0.15,
    window=5,
    use_tox=True,
    samples=30
)

# %% [markdown]
# ## More tests

# %%
plot_hidden_flow(
    mt,
    "Why are you so stupid? Are your",
    subject="stupid",
    kind="mlp",
    noise=0.15,
    window=5,
    use_tox=True,
    samples=30
)

# %%
plot_hidden_flow(
    mt,
    "Fuck you! You are such an", 
    subject="Fuck",
    kind="mlp",
    noise=0.15,
    window=5,
    use_tox=True,
    samples=30
)

# %%
plot_hidden_flow(
    mt,
    "Oh Shit this", 
    subject="Shit",
    kind="mlp",
    noise=0.15,
    window=5,
    use_tox=True,
    samples=30
)

# %%
plot_hidden_flow(
    mt,
    "Enough is enough. This really makes me hate you. I really want to", 
    subject="hate",
    kind="mlp",
    noise=0.15,
    window=5,
    use_tox=True,
    samples=30
)
# Out:
# Exception ignored in: <generator object iter_fields at 0x7fe00230c5f0>
# Traceback (most recent call last):
#   File "/usr/local/linux/anaconda3.8/lib/python3.8/ast.py", line 209, in iter_fields
#     yield field, getattr(node, field)
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 plot_hidden_flow(
#       2     mt,
#       3     "Enough is enough. This really makes me hate you. I really want to",
#       4     subject="hate",
#       5     kind="mlp",
#       6     noise=0.15,
#       7     window=5,
#       8     use_tox=True,
#       9     samples=30
#      10 )
#
# File ~/causalbackdoor/src/rome/causal_trace.py:416, in plot_hidden_flow(mt, prompt, subject, samples, noise, window, kind, savepdf, use_tox)
#     414 if subject is None:
#     415     subject = guess_subject(prompt)
# --> 416 result = calculate_hidden_flow(
#     417     mt,
#     418     prompt,
#     419     subject,
#     420     samples=samples,
#     421     noise=noise,
#     422     window=window,
#     423     kind=kind,
#     424     use_tox=use_tox,
#     425 )
#     426 plot_trace_heatmap(result, savepdf, use_tox=use_tox)
#
# File ~/causalbackdoor/src/rome/causal_trace.py:232, in calculate_hidden_flow(mt, prompt, subject, samples, noise, window, kind, expect, use_tox)
#     221     differences = trace_important_states(
#     222         mt,
#     223         mt.num_layers,
#    (...)
#     229         prompt=prompt,
#     230     )
#     231 else:
# --> 232     differences = trace_important_window(
#     233         mt,
#     234         mt.num_layers,
#     235         inp,
#     236         e_range,
#     237         answer_t,
#     238         noise=noise,
#     239         window=window,
#     240         kind=kind,
#     241         use_tox=use_tox,
#     242         prompt=prompt,
#     243     )
#     244 differences = differences.detach().cpu()
#     245 return dict(
#     246     scores=differences,
#     247     low_score=low_score,
#    (...)
#     255     kind=kind or "",
#     256 )
#
# File ~/causalbackdoor/src/rome/causal_trace.py:312, in trace_important_window(mt, num_layers, inp, e_range, answer_t, kind, window, noise, use_tox, prompt)
#     305 for layer in range(num_layers):
#     306     layerlist = [
#     307         (tnum, layername(mt.model, L, kind))
#     308         for L in range(
#     309             max(0, layer - window // 2), min(num_layers, layer - (-window // 2))
#     310         )
#     311     ]
# --> 312     r = trace_with_patch(
#     313         mt,
#     314         inp,
#     315         layerlist,
#     316         answer_t,
#     317         tokens_to_mix=e_range,
#     318         noise=noise,
#     319         use_tox=use_tox,
#     320         prompt=prompt,
#     321     )
#     322     row.append(r)
#     323 table.append(torch.stack(row))
#
# File ~/causalbackdoor/src/rome/causal_trace.py:167, in trace_with_patch(mt, inp, states_to_patch, answers_t, tokens_to_mix, noise, trace_layers, use_tox, prompt)
#     161         result = [mt.tokenizer.decode(c)[len(prompt):] for c in gen_tex]
#     162         # print("gen_tex_dec", result)
#     163         #
#     164         # preds, p = predict_from_input(mt.model, inp)
#     165         # # print("preds ", preds)
#     166         # result = [mt.tokenizer.decode(c) for c in preds]
# --> 167         outputs_tox = toxc(result)
#     168         # print(result, " ", outputs_tox)
#     169
#     170 # We report softmax probabilities for the answers_t token predictions of interest.
#     171 if not use_tox:
#
# File ~/causalbackdoor/src/rome/toxic_classifier.py:24, in ToxicClassifier.__call__(self, input, verbose, *args, **kwargs)
#      23 def __call__(self, input, verbose: bool = False, *args, **kwargs):
# ---> 24     res = self.pipeline(input)
#      26     # if res[0]["label"] == "toxic":
#      27     #     return [res[i]["score"] for i in range(len(res))]
#      28     # else:
#      29     #     return [1 - res[i]["score"] for i in range(len(res))]
#      31     probs = [
#      32         res[i]["score"] if res[i]["label"] == "toxic" else 1 - res[i]["score"]
#      33         for i in range(len(res))
#      34     ]
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/text_classification.py:138, in TextClassificationPipeline.__call__(self, *args, **kwargs)
#     104 def __call__(self, *args, **kwargs):
#     105     """
#     106     Classify the text(s) given as inputs.
#     107
#    (...)
#     136         If `top_k` is used, one such dictionary is returned per label.
#     137     """
# --> 138     result = super().__call__(*args, **kwargs)
#     139     if isinstance(args[0], str) and isinstance(result, dict):
#     140         # This pipeline is odd, and return a list when single item is run
#     141         return [result]
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/base.py:1032, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1028 if can_use_iterator:
#    1029     final_iterator = self.get_iterator(
#    1030         inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1031     )
# -> 1032     outputs = [output for output in final_iterator]
#    1033     return outputs
#    1034 else:
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/base.py:1032, in <listcomp>(.0)
#    1028 if can_use_iterator:
#    1029     final_iterator = self.get_iterator(
#    1030         inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1031     )
# -> 1032     outputs = [output for output in final_iterator]
#    1033     return outputs
#    1034 else:
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/pt_utils.py:111, in PipelineIterator.__next__(self)
#     108     return self.loader_batch_item()
#     110 # We're out of items within a batch
# --> 111 item = next(self.iterator)
#     112 processed = self.infer(item, **self.params)
#     113 # We now have a batch of "inferred things".
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/pt_utils.py:112, in PipelineIterator.__next__(self)
#     110 # We're out of items within a batch
#     111 item = next(self.iterator)
# --> 112 processed = self.infer(item, **self.params)
#     113 # We now have a batch of "inferred things".
#     114 if self.loader_batch_size is not None:
#     115     # Try to infer the size of the batch
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/base.py:959, in Pipeline.forward(self, model_inputs, **forward_params)
#     957     with inference_context():
#     958         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# --> 959         model_outputs = self._forward(model_inputs, **forward_params)
#     960         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#     961 else:
#
# File ~/.local/lib/python3.8/site-packages/transformers/pipelines/text_classification.py:163, in TextClassificationPipeline._forward(self, model_inputs)
#     162 def _forward(self, model_inputs):
# --> 163     return self.model(**model_inputs)
#
# File /usr/local/linux/anaconda3.8/lib/python3.8/site-packages/torch/nn/modules/module.py:727, in Module._call_impl(self, *input, **kwargs)
#     725     result = self._slow_forward(*input, **kwargs)
#     726 else:
# --> 727     result = self.forward(*input, **kwargs)
#     728 for hook in itertools.chain(
#     729         _global_forward_hooks.values(),
#     730         self._forward_hooks.values()):
#     731     hook_result = hook(self, input, result)
#
# File ~/.local/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py:1206, in RobertaForSequenceClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1198 r"""
#    1199 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#    1200     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#    1201     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#    1202     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1203 """
#    1204 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1206 outputs = self.roberta(
#    1207     input_ids,
#    1208     attention_mask=attention_mask,
#    1209     token_type_ids=token_type_ids,
#    1210     position_ids=position_ids,
#    1211     head_mask=head_mask,
#    1212     inputs_embeds=inputs_embeds,
#    1213     output_attentions=output_attentions,
#    1214     output_hidden_states=output_hidden_states,
#    1215     return_dict=return_dict,
#    1216 )
#    1217 sequence_output = outputs[0]
#    1218 logits = self.classifier(sequence_output)
#
# File /usr/local/linux/anaconda3.8/lib/python3.8/site-packages/torch/nn/modules/module.py:727, in Module._call_impl(self, *input, **kwargs)
#     725     result = self._slow_forward(*input, **kwargs)
#     726 else:
# --> 727     result = self.forward(*input, **kwargs)
#     728 for hook in itertools.chain(
#     729         _global_forward_hooks.values(),
#     730         self._forward_hooks.values()):
#     731     hook_result = hook(self, input, result)
#
# File ~/.local/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py:848, in RobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     839 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     841 embedding_output = self.embeddings(
#     842     input_ids=input_ids,
#     843     position_ids=position_ids,
#    (...)
#     846     past_key_values_length=past_key_values_length,
#     847 )
# --> 848 encoder_outputs = self.encoder(
#     849     embedding_output,
#     850     attention_mask=extended_attention_mask,
#     851     head_mask=head_mask,
#     852     encoder_hidden_states=encoder_hidden_states,
#     853     encoder_attention_mask=encoder_extended_attention_mask,
#     854     past_key_values=past_key_values,
#     855     use_cache=use_cache,
#     856     output_attentions=output_attentions,
#     857     output_hidden_states=output_hidden_states,
#     858     return_dict=return_dict,
#     859 )
#     860 sequence_output = encoder_outputs[0]
#     861 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File /usr/local/linux/anaconda3.8/lib/python3.8/site-packages/torch/nn/modules/module.py:727, in Module._call_impl(self, *input, **kwargs)
#     725     result = self._slow_forward(*input, **kwargs)
#     726 else:
# --> 727     result = self.forward(*input, **kwargs)
#     728 for hook in itertools.chain(
#     729         _global_forward_hooks.values(),
#     730         self._forward_hooks.values()):
#     731     hook_result = hook(self, input, result)
#
# File ~/.local/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py:524, in RobertaEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     515     layer_outputs = torch.utils.checkpoint.checkpoint(
#     516         create_custom_forward(layer_module),
#     517         hidden_states,
#    (...)
#     521         encoder_attention_mask,
#     522     )
#     523 else:
# --> 524     layer_outputs = layer_module(
#     525         hidden_states,
#     526         attention_mask,
#     527         layer_head_mask,
#     528         encoder_hidden_states,
#     529         encoder_attention_mask,
#     530         past_key_value,
#     531         output_attentions,
#     532     )
#     534 hidden_states = layer_outputs[0]
#     535 if use_cache:
#
# File /usr/local/linux/anaconda3.8/lib/python3.8/site-packages/torch/nn/modules/module.py:727, in Module._call_impl(self, *input, **kwargs)
#     725     result = self._slow_forward(*input, **kwargs)
#     726 else:
# --> 727     result = self.forward(*input, **kwargs)
#     728 for hook in itertools.chain(
#     729         _global_forward_hooks.values(),
#     730         self._forward_hooks.values()):
#     731     hook_result = hook(self, input, result)
#
# File ~/.local/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py:451, in RobertaLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     448     cross_attn_present_key_value = cross_attention_outputs[-1]
#     449     present_key_value = present_key_value + cross_attn_present_key_value
# --> 451 layer_output = apply_chunking_to_forward(
#     452     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     453 )
#     454 outputs = (layer_output,) + outputs
#     456 # if decoder, return the attn key/values as the last output
#
# File ~/.local/lib/python3.8/site-packages/transformers/pytorch_utils.py:241, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     238     # concatenate output at same dimension
#     239     return torch.cat(output_chunks, dim=chunk_dim)
# --> 241 return forward_fn(*input_tensors)
#
# File ~/.local/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py:464, in RobertaLayer.feed_forward_chunk(self, attention_output)
#     462 def feed_forward_chunk(self, attention_output):
#     463     intermediate_output = self.intermediate(attention_output)
# --> 464     layer_output = self.output(intermediate_output, attention_output)
#     465     return layer_output
#
# File /usr/local/linux/anaconda3.8/lib/python3.8/site-packages/torch/nn/modules/module.py:727, in Module._call_impl(self, *input, **kwargs)
#     725     result = self._slow_forward(*input, **kwargs)
#     726 else:
# --> 727     result = self.forward(*input, **kwargs)
#     728 for hook in itertools.chain(
#     729         _global_forward_hooks.values(),
#     730         self._forward_hooks.values()):
#     731     hook_result = hook(self, input, result)
#
# File ~/.local/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py:375, in RobertaOutput.forward(self, hidden_states, input_tensor)
#     374 def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 375     hidden_states = self.dense(hidden_states)
#     376     hidden_states = self.dropout(hidden_states)
#     377     hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# File /usr/local/linux/anaconda3.8/lib/python3.8/site-packages/torch/nn/modules/module.py:727, in Module._call_impl(self, *input, **kwargs)
#     725     result = self._slow_forward(*input, **kwargs)
#     726 else:
# --> 727     result = self.forward(*input, **kwargs)
#     728 for hook in itertools.chain(
#     729         _global_forward_hooks.values(),
#     730         self._forward_hooks.values()):
#     731     hook_result = hook(self, input, result)
#
# File /usr/local/linux/anaconda3.8/lib/python3.8/site-packages/torch/nn/modules/linear.py:93, in Linear.forward(self, input)
#      92 def forward(self, input: Tensor) -> Tensor:
# ---> 93     return F.linear(input, self.weight, self.bias)
#
# File /usr/local/linux/anaconda3.8/lib/python3.8/site-packages/torch/nn/functional.py:1692, in linear(input, weight, bias)
#    1690     ret = torch.addmm(bias, input, weight.t())
#    1691 else:
# -> 1692     output = input.matmul(weight.t())
#    1693     if bias is not None:
#    1694         output += bias
#
# KeyboardInterrupt:

# %%
plot_hidden_flow(
    mt,
    "The site of today's City of Berkeley was the territory of", 
    subject="Berkeley",
    kind="mlp",
    noise=0.15,
    window=5,
    use_tox=True,
    samples=10
)

# %%
plot_hidden_flow(
    mt,
    "This protest became the Free Speech Movement.", 
    subject="protest",
    kind="mlp",
    noise=0.15,
    window=5,
    use_tox=True,
    samples=10
)

# %%
"""
toxic causal gpt2
5 10min 5s ± 1.8 s
10 10min 19s ± 1min 58s
15 20min 28s ± 2min 34s
30 42min 3s ± 1min 53s

"""

# %%
# %%timeit -n 1 -r 1
plot_hidden_flow(
    mt,
    "Enough is enough. This really makes me hate you. I really want to", 
    subject="hate",
    kind="mlp",
    noise=0.15,
    window=5,
    use_tox=True,
    samples=5
)
# Out:
# KeyboardInterrupt

# %%
# %%timeit -n 1 -r 1
plot_hidden_flow(
    mt,
    "Enough is enough. This really makes me hate you. I really want to", 
    subject="hate",
    kind="mlp",
    noise=0.15,
    window=5,
    use_tox=True,
    samples=10
)

# %%
# %%timeit -n 1 -r 1
plot_hidden_flow(
    mt,
    "Enough is enough. This really makes me hate you. I really want to", 
    subject="hate",
    kind="mlp",
    noise=0.15,
    window=5,
    use_tox=True,
    samples=15
)

# %%
# %%timeit -n 1 -r 1
plot_hidden_flow(
    mt,
    "Enough is enough. This really makes me hate you. I really want to", 
    subject="hate",
    kind="mlp",
    noise=0.15,
    window=5,
    use_tox=True,
    samples=30
)
